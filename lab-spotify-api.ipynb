# %% [markdown]
# # Lab | Extending the internal databases with audio features
#
# At this point, you have the **hot_songs** and the **not_hot_songs** databases. However, you don't have any acoustic information about the songs.
# The purpose of this lab is to use Spotify's API to extend both databases with this information to use it later.
#
# ## Instructions
#
# * Create a function to search a given **single** song in the Spotify API: **search_song(title, artist, limit)**.
#
# First importing the necessary libraries.

# %%
import pandas as pd
import numpy as np

import sys

# getting the spotify credentials out of this file
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

# %%
# importing the previous created data frames with top 100 hot songs and top 2000 2023 "not hot" songs:

hot_songs = pd.read_csv('billboard_top100.csv')
not_hot_songs = pd.read_csv('not_hot_songs.csv')

# %%
hot_songs.drop(columns='Unnamed: 0', inplace=True)
not_hot_songs.drop(columns='Unnamed: 0', inplace=True)

# %%
hot_songs.head(100)
# Out:
#                                   artist                        title
# 0                            Jack Harlow                  Lovin On Me
# 1                           Taylor Swift                 Cruel Summer
# 2                             Tate McRae                       Greedy
# 3                               Doja Cat           Paint The Town Red
# 4   Zach Bryan Featuring Kacey Musgraves        I Remember Everything
# ..                                   ...                          ...
# 95                            Zach Bryan                   Tourniquet
# 96                              Junior H                      Y Lloro
# 97                   Sophie Ellis-Bextor     Murder On The Dancefloor
# 98                               Karol G                     Amargura
# 99                         Lainey Wilson  Wildflowers And Wild Horses
#
# [100 rows x 2 columns]

# %%
#artists = hot_songs['artist'].to_list()
#titles = hot_songs['title'].to_list()

# %%
hot_songs['title'][0]
# Out:
# 'Lovin On Me'

# %%
"tracks:"+hot_songs['title'][0]+" artist:"+hot_songs['artist'][0]
# Out:
# 'tracks:Lovin On Me artist:Jack Harlow'

# %%
results = sp.search(q="tracks:"+hot_songs['title'][0]+" artist:"+hot_songs['artist'][0],limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=tracks%3ALovin+On+Me+artist%3AJack+Harlow&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'CW',
#       'DM',
#       'FJ',
#       'GE',
#       'GD',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'MV',
#       'MH',
#       'FM',
#       'NR',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'KH',
#       'KG',
#       'LA',
#       'MO',
#       'MN',
#       'NP',
#       'UZ',
#       'IQ',
#       'TJ',
#       'VE',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66eA7wWTKtPnoo3adv9KTZ'},
#      'href': 'https://api.spotify.com/v1/albums/66eA7wWTKtPnoo3adv9KTZ',
#      'id': '66eA7wWTKtPnoo3adv9KTZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737b69dac81192981a9d15e13a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027b69dac81192981a9d15e13a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517b69dac81192981a9d15e13a',
#        'width': 64}],
#      'name': 'Treadmill Tracks',
#      'release_date': '2023-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:66eA7wWTKtPnoo3adv9KTZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ'},
#       'href': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ',
#       'id': '2LIk90788K0zvyj2JJVwkJ',
#       'name': 'Jack Harlow',
#       'type': 'artist',
#       'uri': 'spotify:artist:2LIk90788K0zvyj2JJVwkJ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'CW',
#      'DM',
#      'FJ',
#      'GE',
#      'GD',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'MV',
#      'MH',
#      'FM',
#      'NR',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'KH',
#      'KG',
#      'LA',
#      'MO',
#      'MN',
#      'NP',
#      'UZ',
#      'IQ',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 138411,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT22311371'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RLLhNTZllxd0siTTcaTTM'},
#     'href': 'https://api.spotify.com/v1/tracks/5RLLhNTZllxd0siTTcaTTM',
#     'id': '5RLLhNTZllxd0siTTcaTTM',
#     'is_local': False,
#     'name': 'Lovin on Me',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eeeb6151d0049367b3ad3db0389e9e3b116c0774?cid=6afaab74636b49f99883121af183c121',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:5RLLhNTZllxd0siTTcaTTM'}],
#   'limit': 1,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
json_results = json.dumps(results, ensure_ascii=True)
json_results
# Out:
# '{"tracks": {"href": "https://api.spotify.com/v1/search?query=tracks%3ALovin+On+Me+artist%3AJack+Harlow&type=track&offset=0&limit=1", "items": [{"album": {"album_type": "compilation", "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"}, "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of", "id": "0LyfQWJT6nXafLPZqxe9Of", "name": "Various Artists", "type": "artist", "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"}], "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "SA", "AE", "BH", "QA", "OM", "KW", "LB", "JO", "PS", "IN", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "AG", "AM", "BS", "BB", "BZ", "BT", "CW", "DM", "FJ", "GE", "GD", "GY", "HT", "JM", "KI", "MV", "MH", "FM", "NR", "PW", "PG", "WS", "SM", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "KH", "KG", "LA", "MO", "MN", "NP", "UZ", "IQ", "TJ", "VE", "XK"], "external_urls": {"spotify": "https://open.spotify.com/album/66eA7wWTKtPnoo3adv9KTZ"}, "href": "https://api.spotify.com/v1/albums/66eA7wWTKtPnoo3adv9KTZ", "id": "66eA7wWTKtPnoo3adv9KTZ", "images": [{"height": 640, "url": "https://i.scdn.co/image/ab67616d0000b2737b69dac81192981a9d15e13a", "width": 640}, {"height": 300, "url": "https://i.scdn.co/image/ab67616d00001e027b69dac81192981a9d15e13a", "width": 300}, {"height": 64, "url": "https://i.scdn.co/image/ab67616d000048517b69dac81192981a9d15e13a", "width": 64}], "name": "Treadmill Tracks", "release_date": "2023-12-09", "release_date_precision": "day", "total_tracks": 29, "type": "album", "uri": "spotify:album:66eA7wWTKtPnoo3adv9KTZ"}, "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ"}, "href": "https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ", "id": "2LIk90788K0zvyj2JJVwkJ", "name": "Jack Harlow", "type": "artist", "uri": "spotify:artist:2LIk90788K0zvyj2JJVwkJ"}], "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "SA", "AE", "BH", "QA", "OM", "KW", "LB", "JO", "PS", "IN", "KZ", "MD", "UA", "AL", "BA", "HR", "ME", "MK", "RS", "SI", "KR", "BD", "PK", "LK", "AG", "AM", "BS", "BB", "BZ", "BT", "CW", "DM", "FJ", "GE", "GD", "GY", "HT", "JM", "KI", "MV", "MH", "FM", "NR", "PW", "PG", "WS", "SM", "SB", "KN", "LC", "VC", "SR", "TL", "TO", "TT", "TV", "VU", "AZ", "BN", "KH", "KG", "LA", "MO", "MN", "NP", "UZ", "IQ", "TJ", "VE", "XK"], "disc_number": 1, "duration_ms": 138411, "explicit": true, "external_ids": {"isrc": "USAT22311371"}, "external_urls": {"spotify": "https://open.spotify.com/track/5RLLhNTZllxd0siTTcaTTM"}, "href": "https://api.spotify.com/v1/tracks/5RLLhNTZllxd0siTTcaTTM", "id": "5RLLhNTZllxd0siTTcaTTM", "is_local": false, "name": "Lovin on Me", "popularity": 23, "preview_url": "https://p.scdn.co/mp3-preview/eeeb6151d0049367b3ad3db0389e9e3b116c0774?cid=6afaab74636b49f99883121af183c121", "track_number": 26, "type": "track", "uri": "spotify:track:5RLLhNTZllxd0siTTcaTTM"}], "limit": 1, "next": null, "offset": 0, "previous": null, "total": 1}}'

# %%
results['tracks']['items'][0]['id']
# Out:
# '5RLLhNTZllxd0siTTcaTTM'

# %%
def get_song_ids(df: pd.DataFrame):
    """
    Get the ID of the songs
    """
    import time
    
    list_of_ids = []
    
    # First, we are creating chunks:
    chunk_size = 50
    
    for start in range(0, len(df), chunk_size):
        chunk = df[start:start+chunk_size]
        
        for index, row in chunk.iterrows():
            try:
                #search_song = sp.search(q="tracks:"+df['title'][s]+" artist:"+df['artist'][s],limit=1)
                search_song = sp.search(q=row['title'], limit=1)
                song_id = search_song['tracks']['items'][0]['id']
                list_of_ids.append(song_id)
            
            except:
                print("Song not found!")
                list_of_ids.append("")
                
        print("Sleeping a bit before getting the next ids")
        time.sleep(20)
        
    return list_of_ids

# %%
hot_song_id_list = get_song_ids(hot_songs)
# Out:
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids

# %%
hot_song_id_list
# Out:
# ['4xhsWYTOGcal8zt0J161CU',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '3rUGC1vUpkDG9CZFHMur1t',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '4KULAymBBJcPRpk1yO4dOG',
#  '4iZ4pt7kvcaH6Yo8UoZ4s2',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '59uQI0PADDKeE6UZDTJEe8',
#  '1Lo0QY9cvc8sUB2vnIOxDT',
#  '7dJYggqjKo71KI9sLzqCs8',
#  '0PAcdVzhPO4gq1Iym9ESnK',
#  '6usohdchdzW9oML7VC4Uhk',
#  '1Iq8oo9XkmmvCQiGOfORiz',
#  '0cVyQfDyRnMJ0V3rjjdlU3',
#  '7DSAEUvxU8FajXtRloy8M0',
#  '1yeB8MUNeLo9Ek1UEpsyz6',
#  '1a73gcEg6h6Re6hHXoVltJ',
#  '7MSWxMumjz6lHj7oRApNbg',
#  '0mflMxspEfB0VbI1kyLiAv',
#  '6wf7Yu7cxBSPrRlWeSeK0Q',
#  '1kuGVB7EU95pJObxwvfwKS',
#  '07on0OB2cdPt79IFsgdRUy',
#  '11C4y2Yz1XbHmaQwO06s9f',
#  '4rXLjWdF2ZZpXCVTfWcshS',
#  '5ya0TmUQw2wHMkq36rPsnd',
#  '4OMJGnvZfDvsePyCwRGO7X',
#  '4RvWPyQ5RL0ao9LPZeSouE',
#  '1rnYNAJPAb586NhetosdNW',
#  '7aqfrAY2p9BUSiupwk3svU',
#  '41WQUSINanQHfhfKpFDsms',
#  '3OHfY25tqY28d16oZczHc8',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '2gT2iF1YK5r54A2PDEXVv8',
#  '0R6NfOiLzLj4O5VbYSJAjf',
#  '1o8Z7GD1CeOaVBEyuzu4HO',
#  '73NzYbpaYvQ7JfpjztFESL',
#  '3vkCueOmm7xQDoJ17W1Pm3',
#  '7hZTywPKMdVjJzwdWu11BK',
#  '0HD8mbiPjp3o94X3EaZp0o',
#  '6wsqVwoiVH2kde4k4KKAFU',
#  '2kE2HFBFkJ0VMw3igxYohz',
#  '5mjYQaktjmjcMKcUIcqz4s',
#  '4MjDJD8cW7iVeWInc2Bdyj',
#  '1udwFobQ1JoOdWPQrp2b6u',
#  '6UoKX6uLJwhsnyTp5k5StP',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '6uTPdRrEDeH8Fyg5L5qmeU',
#  '0caJ2wkqp4UmXBwdR2JvB5',
#  '0eBFgRxyVSeuT4iyrbukdn',
#  '5Se32hEA9raeboZerywxka',
#  '2YSzYUF3jWqb9YP9VXmpjE',
#  '6CvTEtGagmzQvkUzzyKR9k',
#  '09hVlIVHtEE1nLUv6YGZiW',
#  '05WVKTdZhlIMX4qqMLuo0f',
#  '5XVdHRf4CAJ2Jm0uMIy5qY',
#  '2Zo1PcszsT9WQ0ANntJbID',
#  '1xWkeSPhf3bZqHY7Ncz8vp',
#  '3XB5uhhlYSnkxpSihkNQwh',
#  '2eGvz6O6tVnh9nKiitDEhZ',
#  '4pCbJC43j3gSqG6Fen6upD',
#  '3CWq0pAKKTWb0K4yiglDc4',
#  '7rr3gguU3TcVnLZD9VzASE',
#  '56xHMIfQPoe0prrSi3BGhf',
#  '4l5w5qGInIhwfvpYmPIYdK',
#  '6fNCrsrdIcgVd2aZZ0nnz4',
#  '73zawW1ttszLRgT9By826D',
#  '0O3U5iwTbiXCREMkvotJuN',
#  '6iiCzEd1ULpq7nXbZVQ4pi',
#  '7CyPwkp0oE8Ro9Dd5CUDjW',
#  '2KslE17cAJNHTsI2MI0jb2',
#  '1ZpPaBDswjV3VSUKqLDXPE',
#  '7iQXYTyuG13aoeHxGG28Nh',
#  '2dPwBKr5uJeCeyd5IoWi8W',
#  '6uIIdjYTxxpWOyWuVXrKQO',
#  '0OWhKvvsHptt6vnnNUSM9a',
#  '158mZIMC4X58ZJK4fJfH1b',
#  '1nQaTUDJ7Rc4yOvZmg9Ozr',
#  '4M68xjcc42oxyphhzpOWXS',
#  '42VsgItocQwOQC3XWZ8JNA',
#  '3IX0yuEVvDbnqUwMBB3ouC',
#  '2OWv3lRR8PtOVuHWzQNRs2',
#  '0NpesW87qtkiKNoB7W4yFk',
#  '4I4G0LD277PWvfblYtSf91',
#  '3eP13S8D5m2cweMEg3ZDed',
#  '78Du4CMFgnhdlG33gblkiP',
#  '4oEf84vBYVftf6KmZexhVo',
#  '5KD6AEm19QnMbfWpfoOHMl',
#  '4qmG24ebshLXtKu9HIShBP',
#  '54zcJnb3tp9c5OVKREZ1Is',
#  '51hyZpbJlIgZIaX3TtMxmu',
#  '3RaCGXCiiMufRPoexXxGkV',
#  '7ELtAKka2YiZRclp70wZ6F',
#  '5jfhLCSIFUO4ndzNRh4w4G',
#  '4kjI1gwQZRKNDkw1nI475M',
#  '3kfhS2L56Wj8fBcu7xE47H',
#  '3EvZ03hGAFwGZ2Ebcu86YH',
#  '6RcAHyC5sAUIbPTkhOQwd8',
#  '4tKGFmENO69tZR9ahgZu48',
#  '505v13epFXodT9fVAJ6h8k',
#  '6d3QUBsiAw3aZI6F2mMhzk']

# %% [markdown]
# Once the desired song is located, **the function should return the href/id/uri of the song to the code** (not to the user) to get the audio features.
#
# * Create a function **get_audio_features(list_of_song_ids)** to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri or a list with a single song IDs).

# %%
def get_audio_features(list_of_song_ids: list):
    """
    Using the song IDs to get the audio features out of the Spotify Database.
    """
    
    import time 
    
    feature_list = []
    feature_df = pd.DataFrame()
    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        #for start in range(0,100,50) -> chunk_size is the increment. second loop will start from chunk_size
        try:
            features = sp.audio_features(tracks=list_of_song_ids[start:start+chunk_size])
            #features = sp.audio_features(tracks=[1,2,3,4,…50])
            
            for f in features:
                df_temp = pd.DataFrame([f])
                feature_df = pd.concat([feature_df, df_temp], ignore_index=True)
        
        except:
            #print(f'Error processing tracks ({i} : {i+chunk_size}) -> {err}')
            print("Error processing tracks")
    print("Sleeping a bit before getting the next ids")
    time.sleep(20)
    
    return feature_df

# %%
hot_song_feature_df = get_audio_features(hot_song_id_list)
# Out:
# Sleeping a bit before getting the next ids

# %%
hot_song_feature_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 1         0.552   0.702    9    -5.707     1       0.1570        0.1170
# 2         0.750   0.733    6    -3.180     0       0.0319        0.2560
# 3         0.868   0.538    5    -8.603     1       0.1740        0.2690
# 4         0.429   0.453    0    -7.746     1       0.0459        0.5540
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0937    0.606  104.983  audio_features
# 1          0.000021    0.1050    0.564  169.994  audio_features
# 2          0.000000    0.1140    0.844  111.018  audio_features
# 3          0.000003    0.0901    0.732   99.968  audio_features
# 4          0.000002    0.1020    0.155   77.639  audio_features
#
#                        id                                   uri  \
# 0  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  1BxfuPKGuaTgP7aM0Bbdwr  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2  3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3  2IGMVunIBsBLtEQyoI1Mu7  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4  4KULAymBBJcPRpk1yO4dOG  spotify:track:4KULAymBBJcPRpk1yO4dOG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3  https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4  https://api.spotify.com/v1/tracks/4KULAymBBJcP...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 2  https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3  https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 4  https://api.spotify.com/v1/audio-analysis/4KUL...       227196
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4

# %%
hot_song_feature_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.943   0.558    2    -4.911     1       0.0568       0.00260
# 1          0.552   0.702    9    -5.707     1       0.1570       0.11700
# 2          0.750   0.733    6    -3.180     0       0.0319       0.25600
# 3          0.868   0.538    5    -8.603     1       0.1740       0.26900
# 4          0.429   0.453    0    -7.746     1       0.0459       0.55400
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.593   0.397    6    -8.309     1       0.0329       0.68400
# 96         0.728   0.589    7    -7.115     1       0.0376       0.42400
# 97         0.730   0.849    1    -5.281     0       0.0299       0.00234
# 98         0.920   0.696    6    -3.356     0       0.0742       0.18300
# 99         0.442   0.644   10    -5.787     0       0.0378       0.34700
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.0937    0.606  104.983  audio_features
# 1           0.000021    0.1050    0.564  169.994  audio_features
# 2           0.000000    0.1140    0.844  111.018  audio_features
# 3           0.000003    0.0901    0.732   99.968  audio_features
# 4           0.000002    0.1020    0.155   77.639  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000007    0.0982    0.320   76.703  audio_features
# 96          0.000008    0.1660    0.767   77.475  audio_features
# 97          0.000026    0.3120    0.887  117.310  audio_features
# 98          0.000000    0.1490    0.545  106.966  audio_features
# 99          0.000002    0.1280    0.340  117.379  audio_features
#
#                         id                                   uri  \
# 0   4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1   1BxfuPKGuaTgP7aM0Bbdwr  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2   3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3   2IGMVunIBsBLtEQyoI1Mu7  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4   4KULAymBBJcPRpk1yO4dOG  spotify:track:4KULAymBBJcPRpk1yO4dOG
# ..                     ...                                   ...
# 95  3EvZ03hGAFwGZ2Ebcu86YH  spotify:track:3EvZ03hGAFwGZ2Ebcu86YH
# 96  6RcAHyC5sAUIbPTkhOQwd8  spotify:track:6RcAHyC5sAUIbPTkhOQwd8
# 97  4tKGFmENO69tZR9ahgZu48  spotify:track:4tKGFmENO69tZR9ahgZu48
# 98  505v13epFXodT9fVAJ6h8k  spotify:track:505v13epFXodT9fVAJ6h8k
# 99  6d3QUBsiAw3aZI6F2mMhzk  spotify:track:6d3QUBsiAw3aZI6F2mMhzk
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1   https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2   https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3   https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4   https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3EvZ03hGAFwG...
# 96  https://api.spotify.com/v1/tracks/6RcAHyC5sAUI...
# 97  https://api.spotify.com/v1/tracks/4tKGFmENO69t...
# 98  https://api.spotify.com/v1/tracks/505v13epFXod...
# 99  https://api.spotify.com/v1/tracks/6d3QUBsiAw3a...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1   https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 2   https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3   https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 4   https://api.spotify.com/v1/audio-analysis/4KUL...       227196
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3EvZ...       189053
# 96  https://api.spotify.com/v1/audio-analysis/6RcA...       179013
# 97  https://api.spotify.com/v1/audio-analysis/4tKG...       230013
# 98  https://api.spotify.com/v1/audio-analysis/505v...       170480
# 99  https://api.spotify.com/v1/audio-analysis/6d3Q...       216573
#
#     time_signature
# 0                4
# 1                4
# 2                1
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %% [markdown]
# * Once the previous function has been created, create another function **add_audio_features(df, audio_features_df)** to concat a given dataframe with the audio features dataframe and return the extended data frame.

# %%
def add_audio_features(df, audio_features_df):
    """
    Concats a given dataframe with the audio features dataframe and return the extended data frame. 
    """
    
    final_df = pd.concat([df, audio_features_df], axis=1)
    
    return final_df

# %%
final_hot_songs = add_audio_features(hot_songs, hot_song_feature_df)

# %%
final_hot_songs.head()
# Out:
#                                  artist                  title  danceability  \
# 0                           Jack Harlow            Lovin On Me         0.943
# 1                          Taylor Swift           Cruel Summer         0.552
# 2                            Tate McRae                 Greedy         0.750
# 3                              Doja Cat     Paint The Town Red         0.868
# 4  Zach Bryan Featuring Kacey Musgraves  I Remember Everything         0.429
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.558    2    -4.911     1       0.0568        0.0026          0.000002
# 1   0.702    9    -5.707     1       0.1570        0.1170          0.000021
# 2   0.733    6    -3.180     0       0.0319        0.2560          0.000000
# 3   0.538    5    -8.603     1       0.1740        0.2690          0.000003
# 4   0.453    0    -7.746     1       0.0459        0.5540          0.000002
#
#    liveness  valence    tempo            type                      id  \
# 0    0.0937    0.606  104.983  audio_features  4xhsWYTOGcal8zt0J161CU
# 1    0.1050    0.564  169.994  audio_features  1BxfuPKGuaTgP7aM0Bbdwr
# 2    0.1140    0.844  111.018  audio_features  3rUGC1vUpkDG9CZFHMur1t
# 3    0.0901    0.732   99.968  audio_features  2IGMVunIBsBLtEQyoI1Mu7
# 4    0.1020    0.155   77.639  audio_features  4KULAymBBJcPRpk1yO4dOG
#
#                                     uri  \
# 0  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4  spotify:track:4KULAymBBJcPRpk1yO4dOG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3  https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4  https://api.spotify.com/v1/tracks/4KULAymBBJcP...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 1  https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 2  https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3  https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 4  https://api.spotify.com/v1/audio-analysis/4KUL...       227196
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4

# %%
not_hot_song_id_list = get_song_ids(not_hot_songs)
# Out:
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids

# %%
len(not_hot_song_id_list)
# Out:
# 1996

# %%
not_hot_song_feature_df = get_audio_features(not_hot_song_id_list)
# Out:
# Sleeping a bit before getting the next ids

# %%
final_not_hot_songs= add_audio_features(not_hot_songs, not_hot_song_feature_df)

# %%
final_hot_songs.to_csv('hot_songs.csv')
final_not_hot_songs.to_csv('not_hot_songs.csv')

# %%
function_file = 'my_function.py'  
with open(function_file, 'a') as file:
    file.write('''
    def get_song_ids(df: pd.DataFrame):
    """
    Get the ID of the songs
    """
    import time
    
    list_of_ids = []
    
    # First, we are creating chunks:
    chunk_size = 50
    
    for start in range(0, len(df), chunk_size):
        chunk = df[start:start+chunk_size]
        
        for index, row in chunk.iterrows():
            try:
                #search_song = sp.search(q="tracks:"+df['title'][s]+" artist:"+df['artist'][s],limit=1)
                search_song = sp.search(q=row['title'], limit=1)
                song_id = search_song['tracks']['items'][0]['id']
                list_of_ids.append(song_id)
            
            except:
                print("Song not found!")
                list_of_ids.append("")
                
        print("Sleeping a bit before getting the next ids")
        time.sleep(20)
        
    return list_of_ids
    
    def get_audio_features(list_of_song_ids: list):
    """
    """
    
    import time 
    
    feature_list = []
    
    # First, we are creating chunks:
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        chunk = list_of_song_ids[start:start+chunk_size]
        
        for i in chunk:
            try:
                my_dict = sp.audio_features([i])[0]
                #my_dict_new = {key : [my_dict[key]] for key in my_dict.keys()}
                feature_list.append(my_dict)
                
            except:
                print("Error retrieving features for song:", i)
    
        print("Sleeping a bit before getting the next ids")
        time.sleep(20)
        
    feature_df = pd.DataFrame(feature_list)
    
    return feature_df
    
    def add_audio_features(df, audio_features_df):
    """
    Concats a given dataframe with the audio features dataframe and return the extended data frame. 
    """
    
    final_df = pd.concat([df, audio_features_df], axis=1)
    
    return final_df
    ''')
